# %%
# Import library

import pandas as pd

# %%
# import csv file

df = pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
# rename multiple columns in a list

df =df.rename(columns ={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_inns_Score','BF':'Balls_Faced','SR':'Batting _Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                 58.6   29  13  7
# 1                186  62.15        1287                91.76    4   7  1
# 2               269*  61.87        2667                55.68    5   4  2
# 3                274  60.97       1707+                54.48    7  11  1
# 4               270*  60.83        416+                   56   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   141  23
# 2   186   5
# 3  246+  11
# 4  104+   1

# %%
# check null values

df.isnull().any()
# Out:
# Player                  False
# Span                    False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_inns_Score      False
# Ave                     False
# Balls_Faced              True
# Batting _Strike_Rate     True
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958       48    81         5  4455
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                  NaN   15  19  6
# 17                220  56.68         NaN                  NaN   15  14  1
#
#       4s  6s
# 9   258+   2
# 17  107+  11

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting _Strike_Rate'] = df['Batting _Strike_Rate'].fillna(0)

# %%
df[df['Player']=='CL Walcott ']
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_inns_Score    Ave  \
# 17  CL Walcott        44    74         7  3798                 220  56.68
#
#    Balls_Faced Batting _Strike_Rate  100  50  0    4s  6s  Start_year  \
# 17           0                    0   15  14  1  107+  11        1948
#
#     End_year Country
# 17      1960      WI

# %%
df.isnull().any()
# Out:
# Player                  False
# Span                    False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_inns_Score      False
# Ave                     False
# Balls_Faced             False
# Batting _Strike_Rate    False
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# dtype: bool

# %%
# drop duplicates

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 54    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50   0  \
# 5                270*  60.83        416+                   56   10   5   2
# 12               365*  57.78       4063+                53.58   26  30  12
# 16                211  56.94       5363+                46.22   15  28   4
# 54               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 5   104+    1
# 12  593+  32+
# 16  276+    8
# 54   991   26

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 53    V Kohli (IND)  2011-2024      113   191        11  8848
# 54    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                   56   10   5   2
# 5                270*  60.83        416+                   56   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# 12               365*  57.78       4063+                53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
# just to check if worked

df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 53    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                   56   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# 15                211  56.94       5363+                46.22   15  28   4
# 53               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 4   104+    1
# 11  593+  32+
# 15  276+    8
# 53   991   26

# %%
# split up span into start and end date + career length
df['Span'].str.split(pat ='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Start_year']=df['Span'].str.split(pat ='-').str[0]

# %%
df['End_year']=df['Span'].str.split(pat ='-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_inns_Score    Ave Balls_Faced Batting _Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                 58.6   29  13   7
# ...

# %%
# drop span columns

df= df.drop(['Span'], axis = 1)

# %%
# Split the country name  from Player

df['Player'].str.split(pat ='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
# We first split the strings in the 'Player' column based on the '('  
#  we extract the second element of the resulting lists using str[1]  similarly for ohter side but wit .str[0]


df['Country']=df['Player'].str.split(pat ='(').str[1].str.split(')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat ='(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1      HC Brook        12    20         1  1181                186  62.15
# 2      AC Voges        20    31         7  1485               269*  61.87
# 3    RG Pollock        23    41         4  2256                274  60.97
# 4    GA Headley        22    40         4  2190               270*  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 61   KD Walters        74   125        14  5357                250  48.26
# 62     GC Smith       117   205        13  9265                277  48.25
# 63  WH Ponsford        29    48         4  2122                266  48.22
# 64    SJ McCabe        39    62         5  2748                232  48.21
# 65   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced Batting _Strike_Rate  100  50   0    4s  6s Start_year  \
# ...

# %%
# change Datatype

df.dtypes
# Out:
# Player                   object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_inns_Score       object
# Ave                     float64
# Balls_Faced              object
# Batting _Strike_Rate     object
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Start_year               object
# End_year                 object
# Country                  object
# dtype: object

# %%
# Highest_inns_Score
# Balls_Faced	
# Batting _Strike_Rate
# Start_year	
# End_year


df['Highest_inns_Score']=df['Highest_inns_Score'].str.split(pat ='*').str[0]

# %%
df['Highest_inns_Score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_inns_Score, Length: 62, dtype: object

# %%
df['Highest_inns_Score']=df['Highest_inns_Score'].astype('int')

# %%
# fixing Balls faced and Batting strike rate

df = df.astype({'Start_year':'int', 'End_year':'int'})

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_inns_Score        int32
# Ave                     float64
# Balls_Faced              object
# Batting _Strike_Rate     object
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Start_year                int32
# End_year                  int32
# Country                  object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10        WR Hammond        85   140        16   7249                 336
# 11         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# ...

# %%
df = df.drop(58, axis= 0)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10        WR Hammond        85   140        16   7249                 336
# 11         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# ...

# %%
df.isnull().any()
# Out:
# Player                  False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_inns_Score      False
# Ave                     False
# Balls_Faced             False
# Batting _Strike_Rate    False
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# Start_year              False
# End_year                False
# Country                 False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_inns_Score        int32
# Ave                     float64
# Balls_Faced              object
# Batting _Strike_Rate     object
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Start_year                int32
# End_year                  int32
# Country                  object
# dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')

# %%
df['Batting _Strike_Rate']=df['Batting _Strike_Rate'].astype('float')

# %%
df['4s']=df['4s'].str.replace('+', '').astype('int')

# %%
df['6s'] = df['6s'].str.replace('+', '').astype('int')

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_inns_Score        int32
# Ave                     float64
# Balls_Faced               int32
# Batting _Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int32
# 6s                        int32
# Start_year                int32
# End_year                  int32
# Country                  object
# dtype: object

# %%
#built new column for Career length

df['career_length']=df['End_year']-df['Start_year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10        WR Hammond        85   140        16   7249                 336
# 11         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# ...

# %%
# Finding avg career length

df['career_length'].mean()
# Out:
# 13.21311475409836

# %%
# avg batting strike rate for players who played over 10 years

df[df['career_length']> 10]['Batting _Strike_Rate'].mean()
# Out:
# 49.061860465116276

# %%
# no. of cricketers who played before 1960
df[df['Start_year']< 1960]['Player'].count()
# Out:
# 22

# %%
# Max highest inns score by country
df.groupby('Country')['Highest_inns_Score'].max().to_frame('HighinnCountry').reset_index().sort_values('HighinnCountry', ascending=False)
# Out:
#     Country  HighinnCountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %%
# Hundreds, 50s 0 avg by country


df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.000000  22.083333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
